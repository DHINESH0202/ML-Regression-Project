# %%
# Import libraries
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# ✅ Download required datasets (FIX INCLUDED)
nltk.download('punkt')
nltk.download('punkt_tab')   # IMPORTANT FIX
nltk.download('stopwords')

# Sample dataset (text + label)
texts = [
    "I love this product",
    "This is amazing",
    "I hate this item",
    "Very bad experience",
    "I am very happy",
    "This is terrible"
]

labels = ["positive", "positive", "negative", "negative", "positive", "negative"]

# Preprocessing function
def preprocess(text):
    text = text.lower()
    tokens = word_tokenize(text)

    # Remove punctuation
    tokens = [word for word in tokens if word not in string.punctuation]

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    return " ".join(tokens)

# Apply preprocessing
cleaned_texts = [preprocess(t) for t in texts]

# Convert text to numbers (Bag of Words)
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(cleaned_texts)

# Train model
model = MultinomialNB()
model.fit(X, labels)

# Test with new sentence
test_text = ["I really love this"]
test_clean = [preprocess(t) for t in test_text]
test_vector = vectorizer.transform(test_clean)

prediction = model.predict(test_vector)

# Output
print("Original Texts:\n", texts)
print("\nCleaned Texts:\n", cleaned_texts)
print("\nTest Sentence:", test_text[0])
print("Predicted Sentiment:", prediction[0])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Original Texts:
#  ['I love this product', 'This is amazing', 'I hate this item', 'Very bad experience', 'I am very happy', 'This is terrible']
#
# Cleaned Texts:
#  ['love product', 'amazing', 'hate item', 'bad experience', 'happy', 'terrible']
#
# Test Sentence: I really love this
# Predicted Sentiment: positive
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
